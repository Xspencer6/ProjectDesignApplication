# %%
import numpy as np
import librosa.display, os
import matplotlib.pyplot as plt
# %matplotlib inline

def create_spectrogram(audio_file, image_file):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1)

    y, sr = librosa.load(audio_file)
    ms = librosa.feature.melspectrogram(y, sr=sr)
    log_ms = librosa.power_to_db(ms, ref=np.max)
    librosa.display.specshow(log_ms, sr=sr)

    fig.savefig(image_file)
    plt.close(fig)
    
def create_pngs_from_json(input_path, output_path):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    dir = os.listdir(input_path)

    for i, file in enumerate(dir):
        input_file = os.path.join(input_path, file)
        output_file = os.path.join(output_path, file.replace('.wav', '.png'))
        create_spectrogram(input_file, output_file)

# %%
# separate files
import os
import shutil

# Define source and destination directories
src_dir = r'Tiles_audio_data\training'
bad_dir = r'TRAINING DATA\Bad Audio'
good_dir = r'TRAINING DATA\Good Audio'

# Create destination directories if they don't exist
os.makedirs(bad_dir, exist_ok=True)
os.makedirs(good_dir, exist_ok=True)

# Iterate through files in the source directory
for filename in os.listdir(src_dir):
    # Check if file is a regular file (not a directory)
    if os.path.isfile(os.path.join(src_dir, filename)):
        # Check if 'Bad' or 'Good' exists in the filename
        if 'Bad' in filename:
            shutil.move(os.path.join(src_dir, filename), bad_dir)
            print(f"Moved {filename} to Bad folder")
        elif 'Good' in filename:
            shutil.move(os.path.join(src_dir, filename), good_dir)
            print(f"Moved {filename} to Good folder")
# Out:
# Moved Bad.2rnnjdj7.ingestion-cc4d66496-8p56s.s9.wav.2rvu223k.ingestion-644665865-q74wd.wav.305il2va.ingestion-66f999547b-xhbtl.json to Bad folder
# Moved Bad.2rnnop6a.ingestion-cc4d66496-8p56s.s10.wav.2rvu2aug.ingestion-644665865-q74wd.wav.305il5b6.ingestion-66f999547b-xhbtl.json to Bad folder
# Moved Bad.2rnnop6a.ingestion-cc4d66496-8p56s.s6.wav.2rvu2a6u.ingestion-644665865-q74wd.wav.305il374.ingestion-66f999547b-9lltr.json to Bad folder
# Moved Bad.2rnnop6a.ingestion-cc4d66496-8p56s.s7.wav.2rvu2age.ingestion-644665865-q74wd.wav.305il3kt.ingestion-66f999547b-prmkk.json to Bad folder
# Moved Bad.2rnnop6a.ingestion-cc4d66496-8p56s.s8.wav.2rvu2als.ingestion-644665865-4fhl5.wav.305il4jo.ingestion-66f999547b-prmkk.json to Bad folder
# Moved Bad.2rnntkre.ingestion-cc4d66496-8p56s.s10.wav.2rvu249t.ingestion-644665865-4fhl5.wav.305il8hn.ingestion-66f999547b-9lltr.json to Bad folder
# ...

# %%
create_pngs_from_wavs('TRAINING DATA\Bad Audio', 'TRAINING DATA\Bad Spectrogram')
# Out:
# C:\Users\spenc\AppData\Local\Temp\ipykernel_25868\1857641683.py:11: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(audio_file)
# c:\Users\spenc\anaconda3\envs\gpuenv\lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File c:\Users\spenc\anaconda3\envs\gpuenv\lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# ...

# %%
create_pngs_from_wavs('TRAINING DATA\Bad Audio', 'TRAINING DATA\Bad Spectrogram')
