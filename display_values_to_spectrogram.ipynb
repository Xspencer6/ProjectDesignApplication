# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
# %matplotlib inline

# %%
testing = r"Tiles_audio_data\testing"
training = r"Tiles_audio_data\training"

# %%
# check if directory is working
for f in os.listdir(testing):
# Out:
# ['Bad.2rnnjdj7.ingestion-cc4d66496-8p56s.s10.wav.2rvu23cq.ingestion-644665865-4fhl5.wav.305il36f.ingestion-66f999547b-prmkk.json',
#  'Bad.2rnnop6a.ingestion-cc4d66496-8p56s.s3.wav.2rvu25pc.ingestion-644665865-q74wd.wav.305il3du.ingestion-66f999547b-xhbtl.json',
#  'Bad.2rnntkre.ingestion-cc4d66496-8p56s.s9.wav.2rvu23ss.ingestion-644665865-q74wd.wav.305il7pp.ingestion-66f999547b-xhbtl.json',
#  'Bad.2rnogkc4.ingestion-cc4d66496-7qjrh.s4.wav.2rvu29gl.ingestion-644665865-q74wd.wav.305ilckl.ingestion-66f999547b-xhbtl.json',
#  'Bad.2rnogkc4.ingestion-cc4d66496-7qjrh.s9.wav.2rvu2aqg.ingestion-644665865-q74wd.wav.305il3md.ingestion-66f999547b-9lltr.json',
#  'Bad.2rnoj108.ingestion-cc4d66496-8p56s.s10.wav.2rvu2egv.ingestion-644665865-zd2bd.wav.305il4r9.ingestion-66f999547b-xhbtl.json',
#  'Bad.2rnoj108.ingestion-cc4d66496-8p56s.s6.wav.2rvu2dbe.ingestion-644665865-q74wd.wav.305il4gj.ingestion-66f999547b-9lltr.json',
# ...

# %%
# display 1 spectrogram of "Bad" tile

# %%
bad_json_data = r"Tiles_audio_data\testing\Bad.2rnnjdj7.ingestion-cc4d66496-8p56s.s10.wav.2rvu23cq.ingestion-644665865-4fhl5.wav.305il36f.ingestion-66f999547b-prmkk.json"
print(json.dumps(bad_json_data))
# Out:
# "Tiles_audio_data\\testing\\Bad.2rnnjdj7.ingestion-cc4d66496-8p56s.s10.wav.2rvu23cq.ingestion-644665865-4fhl5.wav.305il36f.ingestion-66f999547b-prmkk.json"

# %%
bad_json_data.
